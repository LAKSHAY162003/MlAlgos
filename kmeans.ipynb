# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd 

dataset=pd.read_csv("student_clustering.csv")

# %%
dataset # no train test split required !!
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(dataset["cgpa"],dataset["iq"])

# %%
wcss=[]
for i in range(1,11):
    model=KMeans(n_clusters=i,random_state=42)
    model.fit_predict(dataset)
    wcss.append(model.inertia_)
wcss=np.array(wcss)
# Out:
# C:\Users\91931\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91931\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
wcss
# Out:
# array([29957.898288  ,  4184.14127   ,  2364.00558342,   681.96966   ,
#          514.16168032,   398.40391185,   302.54737468,   233.54082486,
#          198.22433644,   179.702929  ])

# %%
plt.plot(np.arange(1,11),wcss)

# %%
dataset = dataset.iloc[:,:].values
model=KMeans(n_clusters=4,random_state=42)

# %%
result=model.fit_predict(dataset) #fits and predicts saath me !!
# Out:
# C:\Users\91931\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
inertia=model.inertia_
print(result)
# Out:
# [1 0 2 2 0 0 2 3 0 2 1 0 2 1 0 2 0 2 0 0 2 1 2 1 1 2 1 3 2 0 3 0 3 0 2 2 3
#  0 1 0 1 2 2 1 3 3 2 0 3 0 1 1 3 2 3 0 0 3 0 3 0 2 2 3 1 3 2 1 0 2 0 3 2 1
#  0 3 0 3 1 2 2 3 0 1 3 1 3 0 3 0 3 3 2 1 2 2 3 2 1 3 0 1 1 3 1 1 2 1 3 3 2
#  3 0 0 2 3 2 0 3 1 1 0 2 3 2 1 2 0 1 2 2 0 1 1 0 3 0 1 2 2 2 1 0 1 1 3 1 3
#  0 1 3 1 3 3 1 2 0 3 0 2 1 3 0 2 3 1 0 1 1 3 3 0 3 1 1 2 3 0 1 3 3 0 0 0 2
#  1 2 2 3 0 2 2 1 1 2 1 3 0 0 3]

# %%
dataset[result==0,1]
# Out:
# array([113., 110., 109., 110., 110., 108., 111., 111., 113., 106., 112.,
#        106., 108., 113., 108., 109., 108., 111., 109., 104., 111., 109.,
#        109., 112., 111., 109., 108., 110., 109., 111., 108., 109., 109.,
#        111., 112., 109., 111., 107., 111., 110., 108., 109., 110., 108.,
#        108., 110., 107., 111., 112., 108.])

# %%
plt.scatter(dataset[result==0,0],dataset[result==0,1],color="Red")
plt.scatter(dataset[result==1,0],dataset[result==1,1],color="Green")
plt.scatter(dataset[result==2,0],dataset[result==2,1],color="Blue")
plt.scatter(dataset[result==3,0],dataset[result==3,1],color="Yellow")
